# %%
import pandas as pd
import csv
# import matplotlib

# %%
acc_data = pd.read_csv('results-accuracy-no-formatting.csv').set_index('method')

acc_data = acc_data.transpose()
acc_data.boxplot(vert=False)

acc_data.stack().reset_index()
# Out:
#            level_0  method       0
# 0            Movie     mas  0.0120
# 1            Movie     bau  0.0000
# 2            Movie     sad  0.0160
# 3            Movie     dem  0.0120
# 4            Movie  random  0.0760
# 5            Movie      ds  0.0120
# 6            Movie    mace  0.0100
# 7            Movie    catd  0.0100
# 8            Movie     gpm  0.0120
# 9            Movie      mv  0.0120
# 10        Temporal     mas  0.0130
# 11        Temporal     bau  0.0195
# 12        Temporal     sad  0.0151
# 13        Temporal     dem  0.0498
# 14        Temporal  random  0.1861
# 15        Temporal      ds  0.0000
# 16        Temporal    mace  0.0021
# 17        Temporal    catd  0.0130
# 18        Temporal     gpm  0.0043
# 19        Temporal      mv  0.0151
# 20             Dog     mas  0.0173
# 21             Dog     bau  0.0471
# 22             Dog     sad  0.0235
# 23             Dog     dem  0.0260
# 24             Dog  random  0.1499
# 25             Dog      ds  0.0000
# ...

# %%
mae_data = pd.read_csv('results-mae-no-formatting.csv').set_index('method')
mae_data = mae_data.transpose()
mae_data
mae_data.boxplot(vert=False)

mae_df = mae_data.stack().reset_index()[['method', 0]]
mae_df.columns = ['method', 'val']
mae_df.plot.scatter(x='method', y='val')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a34ef3c5a333> in <module>()
#       6 mae_df = mae_data.stack().reset_index()[['method', 0]]
#       7 mae_df.columns = ['method', 'val']
# ----> 8 mae_df.plot.scatter(x='method', y='val')
#
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_core.pyc in scatter(self, x, y, s, c, **kwds)
#    3511             ...                       colormap='viridis')
#    3512         """
# -> 3513         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3514
#    3515     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ...

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-b55f15d08dbd> in <module>()
#       1 from matplotlib import pyplot as plt
#       2 get_ipython().magic(u'matplotlib inline')
# ----> 3 import seaborn as sns
#
# ImportError: No module named seaborn
